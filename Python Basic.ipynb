# %% [markdown]
# # 1st Python code

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Comments

# %%
# Single line comments: written using #comment# 
# shortcut key in VS code- Ctrl+/ (forward slash) use for add and remove single line comments.
# Multi line comments: written using ''' comment '''

# %% [markdown]
# # Variables

# %% [markdown]
# # Data Types

# %% [markdown]
# # Operators in Python

# %% [markdown]
# # Control Flow

# %% [markdown]
# # Data Structures
