# %% [markdown]
# # Python-Fundamentals

# %% [markdown]
# ### Indentation

# %%
x = 2
    if x > 0:
        print("x is positive") # This line is indented to belong to the 'if' block
    else:
        print("x is not positive") # This line is indented to belong to the 'else' block
# Out:
#   Cell In[7], line 2
#     if x > 0:
#     ^
# IndentationError: unexpected indent

# %%
x = 2
if x > 0:
    print("x is positive") # This line is not indented to belong to the 'if' block
else:
    print("x is not positive") # This line is not indented to belong to the 'else' block
# Out:
# x is positive

# %%
def my_function(param1, param2):
    """
    This is a docstring for my_function.
    It explains what the function does, its parameters, and what it returns.
    :param param1: The first parameter.
    :param param2: The second parameter.
    :return: The result of some operation.
    """
    return param1 + param2


print(my_function.__doc__)
# Out:
# This is a docstring for my_function.
# It explains what the function does, its parameters, and what it returns.
# :param param1: The first parameter.
# :param param2: The second parameter.
# :return: The result of some operation.

# %%
    """
    This is a multi-line comment
    using a triple-quoted string literal.
    It spans multiple lines and is ignored by the interpreter.
    """
    print("Python")
# Out:
# Python
